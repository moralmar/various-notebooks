# %% [markdown]
# # Pivot Tables - Titanic Data Set
#
# Book: Python Data Science Handbook
# p.170

# %%
import numpy as np
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.groupby("sex")[["survived"]].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
titanic.groupby(["sex", "class"])["survived"].aggregate("mean").unstack() # too much garbled
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.pivot_table("survived", index = "sex", columns = "class")
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
age = pd.cut(titanic["age"], [0, 18, 80])
titanic.pivot_table("survived", [age, "sex"], "class")
# Out:
# class               First    Second     Third
# age      sex
# (0, 18]  female  0.909091  1.000000  0.511628
#          male    0.800000  0.600000  0.215686
# (18, 80] female  0.972973  0.900000  0.423729
#          male    0.375000  0.071429  0.133663

# %%
fare = pd.qcut(titanic["fare"], 2)
titanic.pivot_table("survived", ["sex", age], [fare, "class"])
# Out:
# fare            (-0.001, 14.454]                     (14.454, 512.329]  \
# class                      First    Second     Third             First
# sex    age
# female (0, 18]               NaN  1.000000  0.714286          0.909091
#        (18, 80]              NaN  0.880000  0.444444          0.972973
# male   (0, 18]               NaN  0.000000  0.260870          0.800000
#        (18, 80]              0.0  0.098039  0.125000          0.391304
#
# fare
# class              Second     Third
# sex    age
# female (0, 18]   1.000000  0.318182
#        (18, 80]  0.914286  0.391304
# male   (0, 18]   0.818182  0.178571
#        (18, 80]  0.030303  0.192308

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic2 = titanic[(titanic.sex == "male")&(titanic.adult_male == 0)]
titanic2.head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  \
# 7          0       3  male   2.0      3      1  21.0750        S  Third
# 16         0       3  male   2.0      4      1  29.1250        Q  Third
# 50         0       3  male   7.0      4      1  39.6875        S  Third
# 59         0       3  male  11.0      5      2  46.9000        S  Third
# 63         0       3  male   4.0      3      2  27.9000        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 16  child       False  NaN   Queenstown    no  False
# 50  child       False  NaN  Southampton    no  False
# 59  child       False  NaN  Southampton    no  False
# 63  child       False  NaN  Southampton    no  False

# %%
titanic2.iloc[3,3]=3.
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
titanic2.head()
# Out:
#     survived  pclass   sex  age  sibsp  parch     fare embarked  class    who  \
# 7          0       3  male  2.0      3      1  21.0750        S  Third  child
# 16         0       3  male  2.0      4      1  29.1250        Q  Third  child
# 50         0       3  male  7.0      4      1  39.6875        S  Third  child
# 59         0       3  male  3.0      5      2  46.9000        S  Third  child
# 63         0       3  male  4.0      3      2  27.9000        S  Third  child
#
#     adult_male deck  embark_town alive  alone
# 7        False  NaN  Southampton    no  False
# 16       False  NaN   Queenstown    no  False
# 50       False  NaN  Southampton    no  False
# 59       False  NaN  Southampton    no  False
# 63       False  NaN  Southampton    no  False

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic[(titanic.sex == "male") & (titanic.adult_male == 0)].head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  \
# 7          0       3  male   2.0      3      1  21.0750        S  Third
# 16         0       3  male   2.0      4      1  29.1250        Q  Third
# 50         0       3  male   7.0      4      1  39.6875        S  Third
# 59         0       3  male  11.0      5      2  46.9000        S  Third
# 63         0       3  male   4.0      3      2  27.9000        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 16  child       False  NaN   Queenstown    no  False
# 50  child       False  NaN  Southampton    no  False
# 59  child       False  NaN  Southampton    no  False
# 63  child       False  NaN  Southampton    no  False

# %%
titanic.pivot_table("fare", "class", margins = True)
# Out:
#              fare
# class
# First   84.154687
# Second  20.662183
# Third   13.675550
# All     32.204208

# %% [raw]
# this is a "raw"-field

# %%
titanic.pivot_table("survived", "sex", "class")
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [raw]
# #### this is also a "raw"-field

# %% [markdown]
# this is a markdown field

# %% [markdown]
# #### this is also a markdown field

# %% [markdown]
# ok...now i get it

# %%
titanic.pivot_table(index = "sex",
                   columns = "class",
                   aggfunc = {"survived": "sum",
                             "fare": "mean"})
# Out:
#               fare                       survived
# class        First     Second      Third    First Second Third
# sex
# female  106.125798  21.970121  16.118810       91     70    72
# male     67.226127  19.741782  12.661633       45     17    47
